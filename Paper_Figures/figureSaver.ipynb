# %%
import pickle
import glob
import sys
import numpy as np
sys.path.append('../')
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.style.use('neuron')

# %%
figureFormat = 'svg'

# %%
def simpleaxis(axes, every=False, outward=False):
    if not isinstance(axes, (list, np.ndarray)):
        axes = [axes]
    for ax in axes:
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        if (outward):
            ax.spines['bottom'].set_position(('outward', 10))
            ax.spines['left'].set_position(('outward', 10))
        else:
            ax.spines['bottom'].set_position(('outward', 10))
            ax.spines['left'].set_position(('outward', 10))

        if every:
            ax.spines['bottom'].set_visible(False)
            ax.spines['left'].set_visible(False)
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()
        ax.set_title('')

# %%
for figPick in glob.glob('figures/fig*/*.pkl'):
    figPath = figPick.split('.pkl')[0]
    figname =  figPath + '.' + figureFormat
    figIndex = figPath.split('/')[-1]
    print ('Making ' + figIndex )
    
    with open(figPick,'rb') as fid:
        fig = pickle.load(fid)
    #if figIndex in ['6a','6b','6c','6e','6f','6g','6h','6i','6j','6k']:
    #    axes = fig.axes
    #    simpleaxis(axes)
    #    fig.canvas.draw()
    #axes = fig.axes
    #fig.patch.set_visible(False)
#     for ax in axes:
#         ax.patch.set_visible(False)
#     if figIndex not in ['1c','1f','4a']:
#         pass
#     else:
#         axes = fig.axes
#         for ax in axes:
#             ax.set_aspect(1)
    if figIndex in ['6d','4a']:
        continue
    fig.savefig(figname, transparent=True, bbox_inches='tight')
    plt.close(fig)
# Out:
# Making 4e
# <img src="data:image/png;base64,..." width="216">
# Making 4a1
# <img src="data:image/png;base64,..." width="100">
# Making 4b
# <img src="data:image/png;base64,..." width="216">
# Making 4a3
# <img src="data:image/png;base64,..." width="100">
# Making 4a2
# <img src="data:image/png;base64,..." width="100">
# Making 4a
# <img src="data:image/png;base64,..." width="648">
# Making 4d
# <img src="data:image/png;base64,..." width="216">
# Making 4c
# <img src="data:image/png;base64,..." width="144">
# Making 4e3
# <img src="data:image/png;base64,..." width="144">
# Making 4e2
# <img src="data:image/png;base64,..." width="144">
# Making 4e1
# <img src="data:image/png;base64,..." width="144">
# Making 7a
# <img src="data:image/png;base64,..." width="432">
# Making 6b
# <img src="data:image/png;base64,..." width="108">
# Making 6j
# <img src="data:image/png;base64,..." width="252">
# Making 6f
# <img src="data:image/png;base64,..." width="216">
# Making 6k
# <img src="data:image/png;base64,..." width="432">
# Making 6e
# <img src="data:image/png;base64,..." width="216">
# Making 6g
# <img src="data:image/png;base64,..." width="216">
# Making 6h
# <img src="data:image/png;base64,..." width="216">
# Making 6d
# <img src="data:image/png;base64,..." width="144">
# Making 6i
# <img src="data:image/png;base64,..." width="216">
# Making 6c
# <img src="data:image/png;base64,..." width="144">
# Making 3e
# <img src="data:image/png;base64,..." width="288">
# Making 3f
# <img src="data:image/png;base64,..." width="108">
# Making 3g
# <img src="data:image/png;base64,..." width="108">
# Making 5a
# <img src="data:image/png;base64,..." width="216">
# Making 5b
# <img src="data:image/png;base64,..." width="216">
# Making 2f
# <img src="data:image/png;base64,..." width="432">
# Making 2e
# <img src="data:image/png;base64,..." width="108">
# Making 2f1
# <img src="data:image/png;base64,..." width="108">
# Making 2f2
# <img src="data:image/png;base64,..." width="108">
# Making 2d
# <img src="data:image/png;base64,..." width="108">
# Making 2c
# <img src="data:image/png;base64,..." width="144">
# Making 1k
# <img src="data:image/png;base64,..." width="108">
# Making 1h
# <img src="data:image/png;base64,..." width="108">
# Making 1c
# <img src="data:image/png;base64,..." width="180">
# Making 1g
# <img src="data:image/png;base64,..." width="108">
# Making 1e
# <img src="data:image/png;base64,..." width="108">
# Making 1f
# <img src="data:image/png;base64,..." width="180">
# Making 1m
# <img src="data:image/png;base64,..." width="108">
# Making 1l
# <img src="data:image/png;base64,..." width="108">
# Making 1d
# <img src="data:image/png;base64,..." width="108">
# Making 1j
# <img src="data:image/png;base64,..." width="108">
# Making 1i
# <img src="data:image/png;base64,..." width="108">

# %%
# !rsync -r figures/ /media/sahil/NCBS_Shares_BGStim/patch_data/Paper_Figures/figures/
